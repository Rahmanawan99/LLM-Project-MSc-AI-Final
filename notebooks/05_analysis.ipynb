# %%
import pandas as pd

df = pd.read_csv(
    "../results/baseline_results.csv"
)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   question          100 non-null    object
#  1   generated_answer  100 non-null    object
#  2   best_answer       100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
df["answer_length"] = df["generated_answer"].str.len()

df["answer_length"].describe()
# Out:
# count    100.000000
# mean      22.140000
# std       31.858912
# min        2.000000
# 25%        7.000000
# 50%       11.000000
# 75%       27.000000
# max      196.000000
# Name: answer_length, dtype: float64

# %%
import pandas as pd

baseline = pd.read_csv(
    "../results/baseline_results.csv"
)

rag = pd.read_csv(
    "../results/rag_results.csv"
)


print(
    "Baseline samples:",
    len(baseline)
)

print(
    "RAG samples:",
    len(rag)
)
# Out:
# Baseline samples: 100
# RAG samples: 100
